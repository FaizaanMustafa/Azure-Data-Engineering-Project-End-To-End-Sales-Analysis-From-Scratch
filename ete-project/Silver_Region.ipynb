# %%
df = spark.read.table('`ete-project`.bronze.regions')

# %%
df.display()

# %%
df = df.drop('_rescued_data')

# %%
df.write.format('delta').mode('overwrite').option('path','abfss://silver@azadlsgen7428.dfs.core.windows.net/regions').save()

# %%
# %sql

create table if not exists `ete-project`.silver.region
using delta
location  'abfss://silver@azadlsgen7428.dfs.core.windows.net/regions'
