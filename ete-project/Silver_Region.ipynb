# %%
df = spark.read.format('parquet').load('abfss://sales@adls7428.dfs.core.windows.net/bronze/regions')
df.display()

# %%
df.write.format('delta').mode('append').option('path','abfss://sales@adls7428.dfs.core.windows.net/silver/regions').saveAsTable('ete_project.silver.regions')
