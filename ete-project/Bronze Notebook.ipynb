# %%
dbutils.widgets.text('folder_name','')

# %%
var1 = dbutils.widgets.get('folder_name')

# %%
orders_df = spark.readStream.format('cloudFiles') \
                .option('cloudFiles.format', 'parquet') \
                .option('cloudFiles.schemaLocation', f'abfss://bronze@azadlsgen7428.dfs.core.windows.net/checkpoint_{var1}') \
                .load(f'abfss://source@azadlsgen7428.dfs.core.windows.net/{var1}')

# %%
orders_df.writeStream.format('parquet').outputMode('append').option('checkpointLocation', f'abfss://bronze@azadlsgen7428.dfs.core.windows.net/checkpoint_{var1}').option('path', f'abfss://bronze@azadlsgen7428.dfs.core.windows.net/{var1}').trigger(once=True).start()
