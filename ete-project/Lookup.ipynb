# %%
array = [
    {
        "folder_name":'orders'
    },
    {
        "folder_name":'customers'
    },
    {
        "folder_name":'products'
    }
]

# %%
dbutils.jobs.taskValues.set(key='output_datasests',value =array)
